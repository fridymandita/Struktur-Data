# %% [markdown]
# <a href="https://colab.research.google.com/github/fridymandita/Struktur-Data/blob/main/Struktur_Data_Selection_Sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Selection Sort

# %%
#!curl -s -o setup.sh https://raw.githubusercontent.com/tproffen/ORCSGirlsPython/master/Algorithms/Helpers/setup_activity2.sh
#!bash setup.sh
# Out:
# Fetching needed files ..
# Done

# %%
#%matplotlib inline
#import numpy as np
#from Helpers.helpers import *

# %% [markdown]
# ## Data

# %%
data=[29,99,27,41,66,28,44,78,87,19,31,76,58,88,83,97]

print ("Data: ",data)
# Out:
# Data:  [29, 99, 27, 41, 66, 28, 44, 78, 87, 19, 31, 76, 58, 88, 83, 97]

# %%
updateGraph(1,data)

# %%
def selection_sort(L):
    # i indicates how many items were sorted
    for i in range(len(L)-1):
        # To find the minimum value of the unsorted segment
        # We first assume that the first element is the lowest
        min_index = i
        # We then use j to loop through the remaining elements
        for j in range(i+1, len(L)-1):
            # Update the min_index if the element at j is lower than it
            if L[j] < L[min_index]:
                min_index = j
        # After finding the lowest item of the unsorted regions, swap with the first unsorted item
        L[i], L[min_index] = L[min_index], L[i]

# %%
data=[29,99,27,41,66,28,44,78,87,19,31,76,58,88,83,97]
selection_sort(data)

# Let's see the list after we run the Selection Sort
print(data)
# Out:
# [19, 27, 28, 29, 31, 41, 44, 58, 66, 76, 78, 83, 87, 88, 99, 97]

# %%
updateGraph(1,data)
